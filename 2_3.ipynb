# %%
#Secant Method #8(a)
import math
i=2
def f(x):
    result=math.exp(x)+2**(-x)+2*math.cos(x)-6
    return result

TOL=10**(-5)
p0=1
p1=2
q0=f(p0)
q1=f(p1)
while True:
    p=p1-(f(p1)*(p1-p0))/(f(p1)-f(p0))
    if abs(p-p1)<TOL :
        print(p)
        break
    else:
        i+=1
        p0=p1
        q0=q1
        p1=p
        q1=f(p)
print(i)
# Out:
# 1.8293836019394727
# 7

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(1,2)
plt.scatter(p,q)
plt.plot(x,f(x), c = 'g', alpha = 0.5)

# %%
#10 (a)
import math
i=0
def f(x):
    result=math.exp(x)+2**(-x)+2*math.cos(x)-6
    return result

TOL=10**(-5)
p0=1
p1=2
q0=f(p0)
q1=f(p1)
while True:
    p=p1-(q1*(p1-p0))/(q1-q0)
    if abs(p-p1)<TOL:
        print(p)
        break
    i=i+1
    q=f(p)
    if q*q1<0:
        p0=p1
        q0=q1
    p1=p
    q1=q
print(i)
# Out:
# 1.8293827208408326
# 6

# %%
#section 2.4
#1(a)
import math
i=1
def f(x):
    result=x**2-2*x*math.exp(-x)+math.exp(-2*x)
    return result
TOL=10**(-5)
p0=0
p1=1
q0=f(p0)
q1=f(p1)
while True:
    p=p1-(f(p1)*(p1-p0))/(f(p1)-f(p0))
    if abs(p-p1)<TOL :
        print(p)
        break
    else:
        i+=1
        p0=p1
        q0=q1
        p1=p
        q1=f(p)
print(i)
# Out:
# 0.5671554640759494
# 23

# %%
#3(a)
import math
from scipy.misc import derivative #미분값 구하기.
i=1

def f(x):
    result=x**2-2*x*math.exp(-x)+math.exp(-2*x)
    return result

def f1(x):
    result=2*x-2*math.exp(-2*x)+2*x*math.exp(-x)-2*math.exp(-2*x)
    return result
def f2(x):
    result=2+4*math.exp(-x)-2*x*math.exp(-x)+4*math.exp(-2*x)
    return result

def g(x):
    result=x-((f(x)*f1(x))/(f1(x)**2-f(x)*f2(x)))
    return result
TOL=10**(-5)
p0=0
p1=1
q0=f(p0)
q1=f(p1)
while True:
    p=g(p0)
    if abs(p-p1)<TOL :
        print(p)
        break
    else:
        i+=1
        p0=p1
        q0=q1
        p1=p
        q1=f(p)
print(i)
# Out:
# 0.5683979855536481
# 328

# %%
#2.5 2
from numpy import log as ln
def f(x):
    result=math.exp(6*x)+3*(ln(2)**2)*math.exp(2*x)-ln(8)*math.exp(4*x)-(ln(2))**3
    return result
TOL=10**(-4)*2
def f1(x):
    result=6*math.exp(6*x)+6*(ln(2)**2)*math.exp(2*x)-4*ln(8)*math.exp(4*x)
    return result
p0=0
i=0
while 5:
    p=p0-f(p0)/f1(p0)
    if abs(p-p0)<TOL:
        print(p)
    i+=1
    p0=p
print(i)
# Out:
# -0.18288827513613412
# -0.18301095851703522
# -0.18309277187596965
# -0.1831473261358019
# -0.18318369980496557
# -0.18320795112751578
# -0.18322411344069603
# -0.18323488530682766
# -0.18324206158535106
# -0.1832469188149588
# -0.18325019911224222
# -0.1832521478884816
# -0.18325326827138366
# -0.18325394991233884
# -0.18325284784309362
# -0.18325444447101544
# -0.18325957197494652
# -0.18325885466423047
# -0.18325522023895427
# -0.18325070352712047
# -0.18325258964262786
# -0.18325305321682198
# -0.18325245491026884
# -0.18325375364305196
# -0.18325470167569463
# -0.18325245597845055
# -0.183252889118892
# -0.18325452287090152
# -0.18324897192057882
# -0.1832508297118582
# -0.1832532394433177
# -0.18325524791639614
# -0.18325052273305903
# -0.18325229573799506
# -0.18325269618906315
# -0.18325318637745236
# -0.1832538343412908
# -0.1832508127307321
# -0.18325277249033492
# -0.18325226180683613
# -0.18325344381757824
# -0.1832557336701728
# -0.18324257854493603
# ...

# %%
#2.5 2
from numpy import log as ln
def f(x):
    result=math.exp(6*x)+3*(ln(2)**2)*math.exp(2*x)-ln(8)*math.exp(4*x)-(ln(2))**3
    return result
TOL=10**(-4)*2
def f1(x):
    result=6*math.exp(6*x)+6*(ln(2)**2)*math.exp(2*x)-4*ln(8)*math.exp(4*x)
    return result
p0=0
i=0
while 5:
    p=p0-f(p0)/f1(p0)
    if abs(p-p0)<TOL:
        print(p)
        break
    i+=1
    p0=p
print(i)
# Out:
# -0.18288827513613412
# 15

# %%
#2.6 p0=1일때
from numpy import log as ln
def f(x):
    result=x**3-2*x**2-5
    return result
TOL=10**(-4)
def f1(x):
    result=3*x**2-4*x
    return result
p0=1
i=1
while True:
    p=p0-f(p0)/f1(p0)
    if abs(p-p0)<TOL:
        print(p)
        break
    i+=1
    p0=p
print(i)
# Out:
# 2.6906474480286287
# 22

# %%
#2.6 p0=3일때
from numpy import log as ln
def f(x):
    result=x**3-2*x**2-5
    return result
TOL=10**(-4)
def f1(x):
    result=3*x**2-4*x
    return result
p0=3
i=1
while True:
    p=p0-f(p0)/f1(p0)
    if abs(p-p0)<TOL:
        print(p)
        break
    i+=1
    p0=p
print(i)
# Out:
# 2.690647448028769
# 4
